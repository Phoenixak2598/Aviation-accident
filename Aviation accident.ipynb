# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import date, datetime, timedelta

# %%
data=pd.read_csv('E:\project\Data science\Github\Aviation Accident\Dataset1.csv')
data.head()
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# 2          NaN   NaN     1.0         1.0     0.0
# 3          NaN   NaN    20.0        14.0     0.0
# 4          NaN   NaN    30.0        30.0     0.0
#
#                                              Summary
# 0  During a demonstration flight, a U.S. Army fly...
# 1  First U.S. dirigible Akron exploded just offsh...
# 2  The first fatal airplane accident in Canada oc...
# 3  The airship flew into a thunderstorm and encou...
# 4  Hydrogen gas which was being vented was sucked...

# %%
data.shape
# Out:
# (5268, 13)

# %%
data.isnull().sum()
# Out:
# Date               0
# Time            2219
# Location          20
# Operator          18
# Flight #        4199
# Route           1706
# Type              27
# Registration     335
# cn/In           1228
# Aboard            22
# Fatalities        12
# Ground            22
# Summary          390
# dtype: int64

# %%
data['Time'] = data['Time'].replace(np.nan, '00:00')

# %%
data.isnull().sum()
# Out:
# Date               0
# Time               0
# Location          20
# Operator          18
# Flight #        4199
# Route           1706
# Type              27
# Registration     335
# cn/In           1228
# Aboard            22
# Fatalities        12
# Ground            22
# Summary          390
# dtype: int64

# %%
data['Time'].value_counts()
# Out:
# 00:00    2223
# 15:00      32
# 12:00      31
# 11:00      29
# 19:30      26
#          ...
# 13:16       1
# 19:59       1
# 03:16       1
# 19:37       1
# 16:27       1
# Name: Time, Length: 1005, dtype: int64

# %%
# Replacing the faulty time with proper format
data['Time'] = data['Time'].str.replace('c: ','')
data['Time'] = data['Time'].str.replace('c:','')
data['Time'] = data['Time'].str.replace('c','')
data['Time'] = data['Time'].str.replace('12\'20','12:20')
data['Time'] = data['Time'].str.replace('18.40','18:40')
data['Time'] = data['Time'].str.replace('0943','09:43')
data['Time'] = data['Time'].str.replace('22\'08','22:08')
data['Time'] = data['Time'].str.replace('114:20','00:00')

# %%
# Arrange the time in proper format
data['Time'] = data['Date'] + ' ' +data['Time']

def todate(x):
    return datetime.strptime(x, '%m/%d/%Y %H:%M')

data['Time'] = data['Time'].apply(todate)

# %%
print('Data ranges from ' + str(data.Time.min()) + ' to ' + str(data.Time.max()))
# Out:
# Data ranges from 1908-09-17 17:18:00 to 2009-06-08 00:00:00

# %%
data.Operator = data.Operator.str.upper()

# %%
data.head()
# Out:
#          Date                Time                            Location  \
# 0  09/17/1908 1908-09-17 17:18:00                 Fort Myer, Virginia
# 1  07/12/1912 1912-07-12 06:30:00             AtlantiCity, New Jersey
# 2  08/06/1913 1913-08-06 00:00:00  Victoria, British Columbia, Canada
# 3  09/09/1913 1913-09-09 18:30:00                  Over the North Sea
# 4  10/17/1913 1913-10-17 10:30:00          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    MILITARY - U.S. ARMY      NaN  Demonstration        Wright Flyer III
# 1    MILITARY - U.S. NAVY      NaN    Test flight               Dirigible
# 2                 PRIVATE        -            NaN        Curtiss seaplane
# 3  MILITARY - GERMAN NAVY      NaN            NaN  Zeppelin L-1 (airship)
# 4  MILITARY - GERMAN NAVY      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# 2          NaN   NaN     1.0         1.0     0.0
# 3          NaN   NaN    20.0        14.0     0.0
# 4          NaN   NaN    30.0        30.0     0.0
#
#                                              Summary
# 0  During a demonstration flight, a U.S. Army fly...
# 1  First U.S. dirigible Akron exploded just offsh...
# 2  The first fatal airplane accident in Canada oc...
# 3  The airship flew into a thunderstorm and encou...
# 4  Hydrogen gas which was being vented was sucked...

# %% [markdown]
# # Total Accident by year

# %%
Temp = data.groupby(data.Time.dt.year)[['Date']].count()
Temp.head()
# Out:
#       Date
# Time
# 1908     1
# 1912     1
# 1913     3
# 1915     2
# 1916     5

# %%
# REnaming data with count
Temp = Temp.rename(columns={'Date':'Count'})

# %%
# Plotting the count of accidents by year
plt.figure(figsize=(10,5))
plt.style.use('bmh')
plt.plot(Temp.index, 'Count', data=Temp, color='red', marker='.', linewidth=1.5)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Count of accidents by year', fontsize=18)
plt.show()

# %% [markdown]
# ### We conclude from the graph that from the year 1940 the chance of accidents has increased and it is highest somewhat around 1970 and it has started decreasing after 2000.
# #### Which is good sign :)

# %% [markdown]
# # Plotting the graph against month, week and hour

# %%
import matplotlib.pylab as pl
import matplotlib.gridspec as gridspec

# using the grid graph to display in one go
gs = gridspec.GridSpec(2,2)
pl.figure(figsize=(12,8))
plt.style.use('seaborn-muted')
# Introducing the plot for Count of accident by month 
ax = pl.subplot(gs[0,:])
sns.barplot(data.groupby(data.Time.dt.month)[['Date']].count().index, 'Date',
            data = data.groupby(data.Time.dt.month)[['Date']].count(), color='green', linewidth=2)
plt.xticks(data.groupby(data.Time.dt.month)[['Date']].count().index, 
           ['Jan', 'Feb', 'March', 'April', 'May', 'June', 'July', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.xlabel('Month', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Count of accidents by month', fontsize=14)

# Introducing the plot for Count of accident by week
ax = pl.subplot(gs[1,0])
sns.barplot(data.groupby(data.Time.dt.weekday)[['Date']].count().index, 'Date',
            data = data.groupby(data.Time.dt.weekday)[['Date']].count(), color='skyblue', linewidth=2)
plt.xticks(data.groupby(data.Time.dt.weekday)[['Date']].count().index, 
           ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])
plt.xlabel('Weekday', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Count of accidents by Weekday', fontsize=14)

# Introducing the plot for Count of accident by hour
ax = pl.subplot(gs[1,1])
sns.barplot(data[data.Time.dt.hour != 0].groupby(data.Time.dt.hour )[['Date']].count().index, 'Date',
            data = data[data.Time.dt.hour != 0].groupby(data.Time.dt.hour)[['Date']].count(), color='red', linewidth=2)
plt.xlabel('Hour', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Count of accidents by Hour', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Passenger vs military flights

# %%
# Counting the value of number of military passenger
Temp = data.copy()
Temp['isMilitary'] = Temp.Operator.str.contains('MILITARY') # contain() used which look up the MILITARY word matching in operator column irrespective of other string
Temp = Temp.groupby('isMilitary')[['isMilitary']].count()
Temp.index = ['Passenger', 'Military']
Temp
# Out:
#            isMilitary
# Passenger        4469
# Military          781

# %%
# grouping the military with time and passenger
Temp2 = data.copy()
Temp2['Military'] = Temp2.Operator.str.contains('MILITARY')
Temp2['Passenger'] = Temp2.Military == False
Temp2 = Temp2.loc[:,['Time', 'Military', 'Passenger']]
Temp2
# Out:
#                     Time Military  Passenger
# 0    1908-09-17 17:18:00     True      False
# 1    1912-07-12 06:30:00     True      False
# 2    1913-08-06 00:00:00    False       True
# 3    1913-09-09 18:30:00     True      False
# 4    1913-10-17 10:30:00     True      False
# ...                  ...      ...        ...
# 5263 2009-05-20 06:30:00     True      False
# 5264 2009-05-26 00:00:00    False       True
# 5265 2009-06-01 00:15:00    False       True
# 5266 2009-06-07 08:30:00    False       True
# 5267 2009-06-08 00:00:00     True      False
#
# [5268 rows x 3 columns]

# %%
# grouping the flight accident as military and passenger according to year
Temp2 = Temp2.groupby(Temp2.Time.dt.year)[['Military', 'Passenger']].aggregate(np.count_nonzero)
Temp2
# Out:
#       Military  Passenger
# Time
# 1908         1          0
# 1912         1          0
# 1913         2          1
# 1915         2          0
# 1916         5          0
# ...        ...        ...
# 2005         7         44
# 2006        12         37
# 2007         6         48
# 2008         7         55
# 2009         4         20
#
# [98 rows x 2 columns]

# %%
colors = ['green', 'skyblue']
#creating pie chart of military and passenger
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
patches, texts = plt.pie(Temp.isMilitary, colors=colors, labels=Temp.isMilitary, startangle=90)
plt.legend(patches, Temp.index, fontsize=12)
plt.axis('equal')
plt.title('Total number of accidents by flight type', fontsize=15)

#creating line plot of count of accidents by flight type
plt.subplot(1,2,2)
plt.plot(Temp2.index, 'Military', data=Temp2, color='skyblue', marker='.', linewidth=2)
plt.plot(Temp2.index, 'Passenger', data=Temp2, color='lightgreen', marker='.', linewidth=2)
plt.legend(fontsize=12)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Count of accidents by flight type', fontsize=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Total number of fatalities

# %%
Fatalities = data.groupby(data.Time.dt.year).sum()
Fatalities['Proportion'] = Fatalities['Fatalities'] / Fatalities['Aboard']
# Plotting the graph of abroad vs year and Fatalities vs year
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.fill_between(Fatalities.index, 'Aboard', data=Fatalities, color='skyblue', alpha=0.2)
plt.plot(Fatalities.index, 'Aboard', data=Fatalities, marker='.', color='Slateblue', alpha=0.6, linewidth=1)

plt.fill_between(Fatalities.index, 'Fatalities', data=Fatalities, color='lightgreen', alpha=0.2)
plt.plot(Fatalities.index, 'Fatalities', data=Fatalities, marker='.', color='olive', alpha=0.6, linewidth=1)

plt.legend(fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Number of People', fontsize=14)
plt.title('Total number of Fatalities by Year')

# Plotting the graph between fatalities ratio vs year 

plt.subplot(1,2,2)
plt.plot(Fatalities.index, 'Proportion', data=Fatalities, marker='.', color='red', linewidth=2)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Fatalities ratio', fontsize=14)
plt.title('Fatalities ratio by year', fontsize=16)
plt.show()

# %% [markdown]
# ## Working with second data set

# %%
Totals = pd.read_csv('E:\project\Data science\Github\Aviation Accident\Dataset2.csv')
Totals.head()
# Out:
#   Country Name Country Code                     Indicator Name Indicator Code  \
# 0        Aruba          ABW  Air transport, passengers carried    IS.AIR.PSGR
# 1  Afghanistan          AFG  Air transport, passengers carried    IS.AIR.PSGR
# 2       Angola          AGO  Air transport, passengers carried    IS.AIR.PSGR
# 3      Albania          ALB  Air transport, passengers carried    IS.AIR.PSGR
# 4      Andorra          AND  Air transport, passengers carried    IS.AIR.PSGR
#
#    1960  1961  1962  1963  1964  1965  ...          2011          2012  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN           NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN  ...  2.279341e+06  1.737962e+06
# 2   NaN   NaN   NaN   NaN   NaN   NaN  ...  9.877980e+05  1.132424e+06
# 3   NaN   NaN   NaN   NaN   NaN   NaN  ...  8.297789e+05  8.143397e+05
# 4   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN           NaN
#
#         2013       2014       2015       2016       2017        2018  2019  \
# 0        NaN        NaN        NaN        NaN   223502.0   274280.00   NaN
# 1  2044188.0  2209428.0  1929907.0  1917924.0  1647425.0  1722612.61   NaN
# 2  1321872.0  1409952.0  1244491.0  1482546.0  1375523.0  1516628.00   NaN
# 3   865848.0   151632.0        NaN    26634.0   204090.0   303137.00   NaN
# 4        NaN        NaN        NaN        NaN        NaN         NaN   NaN
#
#    Unnamed: 64
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 65 columns]

# %%
# Removing the unwanted data columns
Totals = Totals.drop(['Country Name', 'Country Code', 'Indicator Code', 'Indicator Name'], axis=1)

# %%
# Replacing the nan values with zero
Totals = Totals.replace(np.nan, 0)

# %%
Totals = pd.DataFrame(Totals.sum())
Totals.tail()
# Out:
#                         0
# 2016         3.104586e+10
# 2017         3.350035e+10
# 2018         3.588238e+10
# 2019         0.000000e+00
# Unnamed: 64  0.000000e+00

# %%
# Assigning new index 
Totals = Totals.drop(Totals.index[0:10])
Totals = Totals['1970':'2008']
Totals.columns = ['Sum']
Totals.index.name = 'Year'
Totals.head()
# Out:
#                Sum
# Year
# 1970  1.850484e+09
# 1971  1.979946e+09
# 1972  1.817426e+09
# 1973  2.388611e+09
# 1974  2.867234e+09

# %%
Fatalities = Fatalities.reset_index()
Fatalities.head()
# Out:
#    Time  Aboard  Fatalities  Ground  Proportion
# 0  1908     2.0         1.0     0.0    0.500000
# 1  1912     5.0         5.0     0.0    1.000000
# 2  1913    51.0        45.0     0.0    0.882353
# 3  1915    60.0        40.0     0.0    0.666667
# 4  1916   109.0       108.0     0.0    0.990826

# %%
Fatalities.Time = Fatalities.Time.apply(str)
Fatalities.index = Fatalities['Time']
del Fatalities['Time']
Fatalities = Fatalities['1970':'2008']
Fatalities = Fatalities[['Fatalities']]
Totals = pd.concat([Totals,Fatalities], axis=1)
Totals['Ratio'] = Totals['Fatalities'] / Totals['Sum'] * 100
Totals.head()
# Out:
#                Sum  Fatalities     Ratio
# 1970  1.850484e+09      2049.0  0.000111
# 1971  1.979946e+09      1932.0  0.000098
# 1972  1.817426e+09      2937.0  0.000162
# 1973  2.388611e+09      2485.0  0.000104
# 1974  2.867234e+09      2318.0  0.000081

# %%
gs = gridspec.GridSpec(2,2)
pl.figure(figsize=(15,10))

# Plotting number of passengers by year
ax= pl.subplot(gs[0,0])
plt.plot(Totals.index, 'Sum', data=Totals, marker='.', color='green', linewidth=1)
plt.xlabel('Year')
plt.ylabel('Number of passengers')
plt.title('Total number of passengers by Year', fontsize=15)
plt.xticks(rotation=90)

# Plotting total number of death by year
x= pl.subplot(gs[0,1])
plt.plot(Fatalities.index, 'Fatalities', data=Totals, marker='.', color='red', linewidth=1)
plt.xlabel('Year')
plt.ylabel('Number of Deaths')
plt.title('Total number of Deaths by Year', fontsize=15)
plt.xticks(rotation=90)

# Plotting fatalities/Total number of passengers ratio by year
x= pl.subplot(gs[1,:])
plt.plot(Totals.index, 'Ratio', data=Totals, marker='.', color='orange', linewidth=1)
plt.xlabel('Year')
plt.ylabel('Ratio')
plt.title('Fatalities/Total number of passengers ratio by Year', fontsize=15)
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Plot ratio and number of deaths in one plot

# %%
fig = plt.figure(figsize=(12,6))
ax1 = fig.subplots()
ax1.plot(Totals.index, 'Ratio', data=Totals, color='orange', marker='.', linewidth=1)
ax1.set_xlabel('Year', fontsize=12)
for label in ax1.xaxis.get_ticklabels():
    label.set_rotation(45)
ax1.set_ylabel('Ratio', color='orange', fontsize=12)
ax1.tick_params('y', colors='orange')
ax2 = ax1.twinx()
ax2.plot(Fatalities.index, 'Fatalities', data=Fatalities, color='green', marker='.', linewidth=1)
ax2.set_ylabel('Number of Fatalities', color='green', fontsize=12)
ax2.tick_params('y', colors='g')
plt.title('Fatalities VS Ratio by year', fontsize=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Operator Analysis

# %%
data.Operator = data.Operator.str.upper()
data.Operator = data.Operator.replace("A B AEROTRANSPORT", 'AB AEROTRANSPORT')

Total_by_Op = data.groupby('Operator')[['Operator']].count()
Total_by_Op = Total_by_Op.rename(columns={'Operator':'Count'})
Total_by_Op = Total_by_Op.sort_values(by='Count', ascending=False).head(10)
Total_by_Op
# Out:
#                                      Count
# Operator
# AEROFLOT                               179
# MILITARY - U.S. AIR FORCE              176
# AIR FRANCE                              70
# DEUTSCHE LUFTHANSA                      65
# AIR TAXI                                48
# UNITED AIR LINES                        44
# CHINA NATIONAL AVIATION CORPORATION     44
# MILITARY - U.S. ARMY AIR FORCES         43
# PAN AMERICAN WORLD AIRWAYS              41
# AMERICAN AIRLINES                       36

# %%
plt.figure(figsize=(12,6))
sns.barplot(y=Total_by_Op.index, x='Count', data=Total_by_Op, palette='gist_heat', orient='h')
plt.xlabel('Count', fontsize=12)
plt.ylabel('Operator', fontsize=12)
plt.title("Total Count of the Operator", fontsize=15)
plt.show()

# %%
Prop_by_Op = data.groupby('Operator')[['Fatalities']].sum()
Prop_by_Op = Prop_by_Op.rename(columns={'Operator':'Fatalities'})
Prop_by_Op = Prop_by_Op.sort_values(by='Fatalities', ascending=False)
Prop_by_OpTop = Prop_by_Op.head(15)

# %%
plt.figure(figsize=(12,6))
sns.barplot(y=Prop_by_OpTop.index, x='Fatalities', data=Prop_by_OpTop, palette='gist_heat', orient='h')
plt.xlabel('Fatalities', fontsize=12)
plt.ylabel('Operator', fontsize=12)
plt.title("Total Fatalities of the Operator", fontsize=15)
plt.show()

# %%
Prop_by_Op[Prop_by_Op['Fatalities'] == Prop_by_Op.Fatalities.min()].index.tolist()
# Out:
# ['MILITARY - EJÉRCITO DEL AIRE',
#  'ARARAT AVIA',
#  'HEWA BORA AIRWAYS',
#  'MILITARY - UKRAINE AIR FORCE',
#  'MILITARY - U.S. AIR FORCE / MILITARY U.S. AIR FORCE',
#  'CANADIAN AIR TRANSAT',
#  'MILITARY U.S. NAVY',
#  'ISLAND SKY FERRY - AIR TAXI',
#  'US AIRWAYS',
#  'SOUTHWEST AIRLINES',
#  'CENTURIAN AIR CARGO',
#  'AMERICAN INTERNATIONAL AIRWAYS',
#  'REGIONAL COMPAGNIE AERIENNE EUROPEENNE',
#  'WESTERN HELICOPTER']

# %%
Aeroflot = data[data.Operator == 'AEROFLOT']
Count_by_year = Aeroflot.groupby(data.Time.dt.year)[['Date']].count()
Count_by_year = Count_by_year.rename(columns={'Date':'Count'})

plt.figure(figsize=(12,6))
plt.plot(Count_by_year.index, 'Count', data=Count_by_year, marker='.', color='red', linewidth=1)
plt.xlabel('Year', fontsize=11)
plt.ylabel('Count', fontsize=11)
plt.title('Count of accidents by year (Aeroflot)', fontsize=16)
plt.show()
